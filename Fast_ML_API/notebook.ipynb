# %%
import pickle
import pandas as pd
from sklearn.neighbors import NearestNeighbors

# %%
DIR = "../attachment_intern/"

# %%
# user id to recommend restaurants for
USER_ID = "u00000"

# load model from pickle file
with open(DIR + "model.pkl", "rb") as f:
    model: NearestNeighbors = pickle.load(f)

# %%
# load user and restaurant data
user_df = pd.read_parquet(DIR + "user.small.parquet")
restaurant_df = pd.read_parquet(DIR + "restaurant.parquet").set_index("index")

# %%
user_df = pd.read_parquet(DIR + "user.parquet")
len(user_df)
# Out:
# 100000

# %%
user_df.head()
# Out:
#   user_id  feature_0  feature_1  feature_2  feature_3  feature_4  feature_5  \
# 0  u00000   0.193018   1.235771   0.478129   0.056068   0.798870   0.942501
# 1  u00001   0.542445   0.061676  -0.172018   0.366714   0.690263   0.565948
# 2  u00002   0.501249   1.194607   0.750967  -0.078167   0.361179   0.124189
# 3  u00003   0.613723  -0.652035   1.161827   0.122698   0.828054  -0.296040
# 4  u00004   0.179650   0.166768   0.337015   0.594367   0.897039   0.858783
#
#    feature_6  feature_7  feature_8  ...  feature_990  feature_991  \
# 0  -0.186956  -0.186927  -0.137488  ...     0.289670     0.529229
# 1   0.030949   0.478960   0.033966  ...    -0.564581     1.279485
# 2   0.736151   1.427973  -0.676132  ...    -0.185844    -0.247236
# 3   0.563028   0.711285   0.097485  ...     0.720368     0.070521
# 4  -0.523686   0.813889   0.517246  ...     0.404695     0.707832
#
#    feature_992  feature_993  feature_994  feature_995  feature_996  \
# 0     0.658945     0.313935     1.343077    -0.160149     1.796040
# 1    -0.600161    -0.370372     1.984003     1.414539     1.877632
# 2     1.687951     0.849775     0.671021    -0.654202    -0.118870
# 3     0.338198     0.885493     0.889271     0.778233     1.164597
# 4     0.700675     1.538892     0.114889     0.793582    -0.071324
#
#    feature_997  feature_998  feature_999
# 0     0.078384     0.460348     0.228150
# 1     1.124837     2.273370     1.369663
# 2     0.419687     0.391202    -0.808181
# 3     0.572195     0.062597    -0.822071
# 4     1.282532    -0.052153     0.395376
#
# [5 rows x 1001 columns]

# %%
restaurant_df.head(), len(restaurant_df)
# Out:
# (      restaurant_id            latitude           longitude
#  index
#  0             r0000  13.844851141246949   100.3086836106867
#  1             r0001  13.781825896541061  100.84977532273388
#  2             r0002  13.883572268183674   100.3085459374542
#  3             r0003  14.066725452665281   100.7256760943531
#  4             r0004  13.961173933525883  100.39580661948798,
#  10000)

# %%
user_df[user_df["user_id"] == USER_ID].drop(columns="user_id").shape
# Out:
# (1, 1000)

# %%
# find 20 nearest neighbors to be recommend restaurants
dist, ind = model.kneighbors(
    user_df[user_df["user_id"] == USER_ID].drop(columns="user_id"), n_neighbors=20
)

dist, ind
# Out:
# (array([[23.66758003, 23.80081254, 23.83828907, 24.07205225, 24.16645254,
#          24.18236662, 24.22441798, 24.23519259, 24.23628432, 24.26967065,
#          24.27378404, 24.28877668, 24.29956383, 24.30405023, 24.30567711,
#          24.33704798, 24.34151423, 24.34254504, 24.35122189, 24.35462439]]),
#  array([[1737, 2116,  862, 1060, 5083, 4855, 7495, 7182, 9669, 8749, 2316,
#          2159, 4255, 7596, 7523,  782, 7075, 2751, 3382, 9548]]))

# %%
# get restaurant id from restaurant indices returned from the model
recommend_df = restaurant_df.loc[ind[0]]

# set distance as restaurant score
recommend_df["score"] = dist[0]

# %%
ind[0].shape
# Out:
# (20,)

# %%
print(recommend_df[["restaurant_id", "score"]].to_json(orient="records", indent=2))
# Out:
# [
#   {
#     "restaurant_id":"r1737",
#     "score":23.6675800283
#   },
#   {
#     "restaurant_id":"r2116",
#     "score":23.8008125402
#   },
#   {
#     "restaurant_id":"r0862",
#     "score":23.8382890655
#   },
#   {
#     "restaurant_id":"r1060",
#     "score":24.0720522494
#   },
#   {
#     "restaurant_id":"r5083",
#     "score":24.166452545
#   },
#   {
#     "restaurant_id":"r4855",
#     "score":24.182366617
#   },
#   {
#     "restaurant_id":"r7495",
#     "score":24.2244179801
#   },
#   {
#     "restaurant_id":"r7182",
#     "score":24.2351925876
#   },
#   {
#     "restaurant_id":"r9669",
#     "score":24.2362843205
#   },
#   {
#     "restaurant_id":"r8749",
#     "score":24.2696706463
#   },
#   {
#     "restaurant_id":"r2316",
#     "score":24.2737840441
#   },
#   {
#     "restaurant_id":"r2159",
#     "score":24.2887766768
#   },
#   {
#     "restaurant_id":"r4255",
#     "score":24.2995638295
#   },
#   {
#     "restaurant_id":"r7596",
#     "score":24.3040502318
#   },
#   {
#     "restaurant_id":"r7523",
#     "score":24.3056771101
#   },
#   {
#     "restaurant_id":"r0782",
#     "score":24.3370479842
#   },
#   {
#     "restaurant_id":"r7075",
#     "score":24.3415142344
#   },
#   {
#     "restaurant_id":"r2751",
#     "score":24.3425450391
#   },
#   {
#     "restaurant_id":"r3382",
#     "score":24.3512218859
#   },
#   {
#     "restaurant_id":"r9548",
#     "score":24.3546243861
#   }
# ]

# %%
request_df = pd.read_parquet(DIR + "request.parquet")
request_df.head()
# Out:
#   user_id   latitude   longitude  size  sort_dis  max_dis
# 0  u83153  14.068817  100.646536    50       0.0   5000.0
# 1  u45712  14.109562  100.698690    50       1.0   5000.0
# 2  u52829  13.727387  100.830825    50       1.0   5000.0
# 3  u11570  13.921809  100.468203    20       1.0   5000.0
# 4  u99991  13.804917  100.682749    50       NaN   5000.0

# %%
request_df.to_dict(orient="records")
# Out:
# [{'user_id': 'u83153',
#   'latitude': 14.068817471971206,
#   'longitude': 100.64653564859792,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u45712',
#   'latitude': 14.109562142994584,
#   'longitude': 100.6986897188348,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u52829',
#   'latitude': 13.72738690784919,
#   'longitude': 100.83082543338223,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u11570',
#   'latitude': 13.921808757777047,
#   'longitude': 100.46820296398501,
#   'size': 20,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u99991',
#   'latitude': 13.804916705815488,
#   'longitude': 100.68274869836898,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u38657',
#   'latitude': 13.755984152670258,
#   'longitude': 100.52460461785762,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 10000.0},
#  {'user_id': 'u95302',
#   'latitude': 14.030551991846853,
#   'longitude': 100.79957194321223,
#   'size': 20,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u98542',
#   'latitude': 13.945146555991373,
#   'longitude': 100.76149479839995,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u48207',
#   'latitude': 13.777138513782543,
#   'longitude': 100.72740642981746,
#   'size': 20,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u90260',
#   'latitude': 13.901777277057704,
#   'longitude': 100.6368179920511,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u77275',
#   'latitude': 14.129160266715685,
#   'longitude': 100.44947967792828,
#   'size': 20,
#   'sort_dis': 0.0,
#   'max_dis': 10000.0},
#  {'user_id': 'u24142',
#   'latitude': 13.915768079581238,
#   'longitude': 100.80725407632717,
#   'size': 20,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u19110',
#   'latitude': 14.12041030175016,
#   'longitude': 100.84097821978753,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u55947',
#   'latitude': 13.915357443625616,
#   'longitude': 100.83052184736202,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u79870',
#   'latitude': 14.166851515149292,
#   'longitude': 100.49191712898903,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 1000.0},
#  {'user_id': 'u30189',
#   'latitude': 13.598519516194438,
#   'longitude': 100.75968171609486,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u84837',
#   'latitude': 13.852767632053784,
#   'longitude': 100.68049276467255,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 10000.0},
#  {'user_id': 'u39398',
#   'latitude': 13.907231603374035,
#   'longitude': 100.7695458395559,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u30992',
#   'latitude': 14.010234068990766,
#   'longitude': 100.74870797583915,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u87351',
#   'latitude': 14.152993127640103,
#   'longitude': 100.5562994603071,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u31366',
#   'latitude': 13.949147880455614,
#   'longitude': 100.52346059666596,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u18178',
#   'latitude': 13.863411617002974,
#   'longitude': 100.7450939278356,
#   'size': 20,
#   'sort_dis': 0.0,
#   'max_dis': 1000.0},
#  {'user_id': 'u01785',
#   'latitude': 13.955613648878861,
#   'longitude': 100.66703734227701,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 1000.0},
#  {'user_id': 'u72540',
#   'latitude': 13.896097645238884,
#   'longitude': 100.60338914930433,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 1000.0},
#  {'user_id': 'u71804',
#   'latitude': 13.997332944584763,
#   'longitude': 100.7883411393146,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u20783',
#   'latitude': 14.140140617130532,
#   'longitude': 100.32231718099791,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u65742',
#   'latitude': 13.589542884699403,
#   'longitude': 100.3121258374523,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u87643',
#   'latitude': 13.770392680079276,
#   'longitude': 100.56194877291159,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u63141',
#   'latitude': 14.098485115546948,
#   'longitude': 100.35858265481784,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': nan},
#  {'user_id': 'u28127',
#   'latitude': 13.616529597211741,
#   'longitude': 100.7708958661126,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u30233',
#   'latitude': 14.047692562177868,
#   'longitude': 100.35350650402147,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u95987',
#   'latitude': 13.599555332543218,
#   'longitude': 100.79299638670392,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u27606',
#   'latitude': 13.963833821567123,
#   'longitude': 100.42927139165246,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u80549',
#   'latitude': 14.053612343054304,
#   'longitude': 100.37889238374244,
#   'size': 20,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u49607',
#   'latitude': 13.721829657337835,
#   'longitude': 100.72193613212026,
#   'size': 20,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u13621',
#   'latitude': 13.806291626070298,
#   'longitude': 100.67979542836184,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u90815',
#   'latitude': 13.714939239598559,
#   'longitude': 100.53187551852352,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u99638',
#   'latitude': 13.997222742238831,
#   'longitude': 100.63473072777829,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u72799',
#   'latitude': 13.893376649095266,
#   'longitude': 100.61083952445992,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u89100',
#   'latitude': 13.93870970001385,
#   'longitude': 100.8297774802674,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u86580',
#   'latitude': 13.773406383929899,
#   'longitude': 100.58566173962635,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u28592',
#   'latitude': 13.92755628174842,
#   'longitude': 100.60341526234943,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u93707',
#   'latitude': 14.144567402722975,
#   'longitude': 100.56045483989334,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u42326',
#   'latitude': 14.04114663570355,
#   'longitude': 100.53266349391973,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u56897',
#   'latitude': 14.1429766907122,
#   'longitude': 100.68665052090293,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u14016',
#   'latitude': 13.727206633197833,
#   'longitude': 100.36644708896259,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u30152',
#   'latitude': 13.885845933981953,
#   'longitude': 100.68791850739713,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': nan},
#  {'user_id': 'u68512',
#   'latitude': 13.808930988200323,
#   'longitude': 100.81872151889898,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u45156',
#   'latitude': 13.785550474737597,
#   'longitude': 100.72602349713982,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u64455',
#   'latitude': 14.055435033458183,
#   'longitude': 100.60527568740154,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u25057',
#   'latitude': 13.68458493254948,
#   'longitude': 100.50035220268236,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u69640',
#   'latitude': 13.91092667152094,
#   'longitude': 100.3587674195628,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u31990',
#   'latitude': 14.038114374869417,
#   'longitude': 100.35582650141941,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u23661',
#   'latitude': 14.13338513391439,
#   'longitude': 100.60319675995214,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 10000.0},
#  {'user_id': 'u64183',
#   'latitude': 13.592312751964736,
#   'longitude': 100.79187563038323,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u57944',
#   'latitude': 13.741086647569954,
#   'longitude': 100.78412867638566,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u18933',
#   'latitude': 13.872290563828416,
#   'longitude': 100.4062052211248,
#   'size': 20,
#   'sort_dis': 0.0,
#   'max_dis': 1000.0},
#  {'user_id': 'u37694',
#   'latitude': 14.133900571172934,
#   'longitude': 100.71941598404527,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': nan},
#  {'user_id': 'u31100',
#   'latitude': 13.677618235725772,
#   'longitude': 100.75150129828573,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u03723',
#   'latitude': 14.077502231504093,
#   'longitude': 100.57037822831639,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u95967',
#   'latitude': 13.815714850547252,
#   'longitude': 100.77980150323373,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': nan},
#  {'user_id': 'u91741',
#   'latitude': 13.904605555276143,
#   'longitude': 100.4080612077108,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u02445',
#   'latitude': 14.128954736470062,
#   'longitude': 100.49045003363268,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u56494',
#   'latitude': 13.619243925683307,
#   'longitude': 100.58933639031243,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u80211',
#   'latitude': 13.77577987683665,
#   'longitude': 100.70697422102964,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 1000.0},
#  {'user_id': 'u27929',
#   'latitude': 13.673264038867764,
#   'longitude': 100.5531411707202,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u53464',
#   'latitude': 13.660282752444203,
#   'longitude': 100.47196630988599,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 10000.0},
#  {'user_id': 'u93068',
#   'latitude': 13.760490412699326,
#   'longitude': 100.78459878779759,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u52924',
#   'latitude': 13.994856889890464,
#   'longitude': 100.5216456349738,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 1000.0},
#  {'user_id': 'u33917',
#   'latitude': 13.92383955555286,
#   'longitude': 100.53698936832163,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u52470',
#   'latitude': 13.653203050354339,
#   'longitude': 100.4284927086221,
#   'size': 20,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u62714',
#   'latitude': 14.054295961884602,
#   'longitude': 100.57207793345606,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u63264',
#   'latitude': 13.880694838634698,
#   'longitude': 100.69561165381624,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u27911',
#   'latitude': 13.665812096588787,
#   'longitude': 100.50494513105092,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u18692',
#   'latitude': 14.065492427507852,
#   'longitude': 100.6712373845912,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u02066',
#   'latitude': 14.065687063538446,
#   'longitude': 100.57778441313081,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u13358',
#   'latitude': 13.709245939779338,
#   'longitude': 100.3112814333247,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u42410',
#   'latitude': 14.135788103986393,
#   'longitude': 100.83739529804845,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u48040',
#   'latitude': 14.059543652293534,
#   'longitude': 100.4641670623369,
#   'size': 20,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u38688',
#   'latitude': 13.71653180462484,
#   'longitude': 100.60681255815969,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u56052',
#   'latitude': 13.581918351995894,
#   'longitude': 100.83547179007958,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u48510',
#   'latitude': 14.093160974923412,
#   'longitude': 100.41912975429389,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u52350',
#   'latitude': 14.068796371076255,
#   'longitude': 100.34010299886339,
#   'size': 20,
#   'sort_dis': 0.0,
#   'max_dis': 10000.0},
#  {'user_id': 'u70919',
#   'latitude': 13.638916629698775,
#   'longitude': 100.41840947960516,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 1000.0},
#  {'user_id': 'u29021',
#   'latitude': 14.033617953887084,
#   'longitude': 100.38937924813573,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u18427',
#   'latitude': 14.037581117196135,
#   'longitude': 100.77588961905496,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': nan},
#  {'user_id': 'u09262',
#   'latitude': 13.95530679008866,
#   'longitude': 100.59102301324354,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u53965',
#   'latitude': 14.072607593211377,
#   'longitude': 100.32795500800503,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u90739',
#   'latitude': 14.162478072795038,
#   'longitude': 100.45505998895834,
#   'size': 20,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u36031',
#   'latitude': 13.774756628064194,
#   'longitude': 100.58761930052876,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 10000.0},
#  {'user_id': 'u54636',
#   'latitude': 14.073443335319594,
#   'longitude': 100.40121570061345,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u30252',
#   'latitude': 14.124813015902621,
#   'longitude': 100.47430284443945,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u25262',
#   'latitude': 13.766351634069546,
#   'longitude': 100.80543725141838,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u06877',
#   'latitude': 13.984672780721924,
#   'longitude': 100.5507904760349,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u29601',
#   'latitude': 13.985185276568227,
#   'longitude': 100.43380428223757,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u17059',
#   'latitude': 14.082242251840462,
#   'longitude': 100.6354907197874,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u52433',
#   'latitude': 13.915850993473562,
#   'longitude': 100.36713733724707,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u85268',
#   'latitude': 13.743985843245724,
#   'longitude': 100.59252657379163,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u97601',
#   'latitude': 13.72982983314441,
#   'longitude': 100.66332553179636,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u71518',
#   'latitude': 13.90163818163863,
#   'longitude': 100.35382229469079,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u69548',
#   'latitude': 13.661194863079265,
#   'longitude': 100.60834076973,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u48395',
#   'latitude': 14.088560507633758,
#   'longitude': 100.47600283856212,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u29703',
#   'latitude': 14.106066205656232,
#   'longitude': 100.71692799052728,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u93342',
#   'latitude': 13.724304127944002,
#   'longitude': 100.64559474897636,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u03553',
#   'latitude': 13.992778943212612,
#   'longitude': 100.80813242474846,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u28827',
#   'latitude': 13.978593602710474,
#   'longitude': 100.64082943609036,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u70333',
#   'latitude': 13.653237838874958,
#   'longitude': 100.40601016312601,
#   'size': 20,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u79687',
#   'latitude': 14.040680095613057,
#   'longitude': 100.40740103972013,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u59021',
#   'latitude': 14.033552551641979,
#   'longitude': 100.69425128719409,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 1000.0},
#  {'user_id': 'u54693',
#   'latitude': 13.76210253276385,
#   'longitude': 100.75327060468179,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u07152',
#   'latitude': 13.639257714724529,
#   'longitude': 100.33933494224392,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 1000.0},
#  {'user_id': 'u18276',
#   'latitude': 13.747640240631002,
#   'longitude': 100.53548211465194,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u83604',
#   'latitude': 14.036672848977233,
#   'longitude': 100.46127874014873,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u22291',
#   'latitude': 13.856737872648733,
#   'longitude': 100.56343081091715,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': nan},
#  {'user_id': 'u24161',
#   'latitude': 14.062471739914907,
#   'longitude': 100.78763366945698,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 10000.0},
#  {'user_id': 'u86211',
#   'latitude': 13.675513357378632,
#   'longitude': 100.61452280966897,
#   'size': 20,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u22386',
#   'latitude': 13.644183421061216,
#   'longitude': 100.71665064029615,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u99767',
#   'latitude': 13.78728162094177,
#   'longitude': 100.728087110536,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u71391',
#   'latitude': 14.10055187454367,
#   'longitude': 100.45841107522479,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 10000.0},
#  {'user_id': 'u57269',
#   'latitude': 13.676847339744768,
#   'longitude': 100.6471889730452,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u59433',
#   'latitude': 13.624650280103483,
#   'longitude': 100.51236735775973,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u07652',
#   'latitude': 14.025612003831124,
#   'longitude': 100.56722113656546,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 10000.0},
#  {'user_id': 'u26874',
#   'latitude': 13.635215407605802,
#   'longitude': 100.59836154996769,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': nan},
#  {'user_id': 'u78156',
#   'latitude': 13.975392489820086,
#   'longitude': 100.67393701453591,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': nan},
#  {'user_id': 'u18272',
#   'latitude': 13.630579457576902,
#   'longitude': 100.39792167955962,
#   'size': 20,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u41964',
#   'latitude': 13.726998979737363,
#   'longitude': 100.76876337633699,
#   'size': 20,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u91265',
#   'latitude': 13.972928169581428,
#   'longitude': 100.39384148994306,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 10000.0},
#  {'user_id': 'u59933',
#   'latitude': 14.096843339590123,
#   'longitude': 100.47799530994558,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u48600',
#   'latitude': 13.822800935438615,
#   'longitude': 100.77478298175578,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u03853',
#   'latitude': 13.846638396099813,
#   'longitude': 100.85006274518447,
#   'size': 20,
#   'sort_dis': 0.0,
#   'max_dis': 10000.0},
#  {'user_id': 'u73761',
#   'latitude': 13.59966829126995,
#   'longitude': 100.50771723673566,
#   'size': 20,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u05621',
#   'latitude': 13.782353373955829,
#   'longitude': 100.83168900621838,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u48240',
#   'latitude': 13.724168870632608,
#   'longitude': 100.32543403690214,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u34893',
#   'latitude': 14.046746565337374,
#   'longitude': 100.83348574052725,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u53996',
#   'latitude': 14.002812555034213,
#   'longitude': 100.41596133035654,
#   'size': 20,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u21367',
#   'latitude': 14.044208742050687,
#   'longitude': 100.32405650001775,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u15698',
#   'latitude': 13.895109976671453,
#   'longitude': 100.72649830206493,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u99925',
#   'latitude': 13.994053846903178,
#   'longitude': 100.3940550166781,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 10000.0},
#  {'user_id': 'u54776',
#   'latitude': 13.65640265319202,
#   'longitude': 100.72105167265806,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u56742',
#   'latitude': 13.80856196611725,
#   'longitude': 100.30859902933084,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u84652',
#   'latitude': 13.754198359582205,
#   'longitude': 100.37331005298061,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': nan},
#  {'user_id': 'u20000',
#   'latitude': 13.747855488955983,
#   'longitude': 100.50262176403128,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u04033',
#   'latitude': 14.017540227075251,
#   'longitude': 100.35144832580666,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u20198',
#   'latitude': 13.707701816716941,
#   'longitude': 100.56550177319924,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u45313',
#   'latitude': 13.773322445062597,
#   'longitude': 100.49628023876511,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u30042',
#   'latitude': 13.747984088677416,
#   'longitude': 100.71352141996465,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u32250',
#   'latitude': 14.091202606245304,
#   'longitude': 100.57754711991747,
#   'size': 20,
#   'sort_dis': 0.0,
#   'max_dis': 10000.0},
#  {'user_id': 'u20598',
#   'latitude': 13.958111676902229,
#   'longitude': 100.83901843436797,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u73348',
#   'latitude': 13.864954265176094,
#   'longitude': 100.77162688152212,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u61250',
#   'latitude': 13.805483390426208,
#   'longitude': 100.39945254235957,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u16479',
#   'latitude': 14.125190110482729,
#   'longitude': 100.81249499581122,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 10000.0},
#  {'user_id': 'u04063',
#   'latitude': 14.135683118529627,
#   'longitude': 100.8000112220801,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u24381',
#   'latitude': 13.846674651360996,
#   'longitude': 100.6174472218171,
#   'size': 20,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u93811',
#   'latitude': 13.915825123051489,
#   'longitude': 100.59635679131536,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u92070',
#   'latitude': 14.090312656205967,
#   'longitude': 100.39877467715446,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 1000.0},
#  {'user_id': 'u71880',
#   'latitude': 13.732636050480632,
#   'longitude': 100.48237992483584,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u57194',
#   'latitude': 13.733952336575209,
#   'longitude': 100.42654917406621,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 10000.0},
#  {'user_id': 'u55293',
#   'latitude': 13.642179432606303,
#   'longitude': 100.41324210948305,
#   'size': 20,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u97221',
#   'latitude': 13.877557141746678,
#   'longitude': 100.64463407730055,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u57260',
#   'latitude': 14.03481122611402,
#   'longitude': 100.48431099544752,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 1000.0},
#  {'user_id': 'u43591',
#   'latitude': 13.673707309744506,
#   'longitude': 100.72962779624838,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u12305',
#   'latitude': 13.836520632480294,
#   'longitude': 100.62199496551013,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u22209',
#   'latitude': 14.165924811875133,
#   'longitude': 100.76262151768933,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u34400',
#   'latitude': 13.865285073856981,
#   'longitude': 100.3531151310954,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 10000.0},
#  {'user_id': 'u83679',
#   'latitude': 13.806978919700752,
#   'longitude': 100.77363980865208,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u28320',
#   'latitude': 14.07669679296809,
#   'longitude': 100.58573618087351,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u37355',
#   'latitude': 14.107776919967717,
#   'longitude': 100.65461474142728,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 1000.0},
#  {'user_id': 'u36372',
#   'latitude': 13.80327375722921,
#   'longitude': 100.43669276642275,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u07858',
#   'latitude': 13.65421516487502,
#   'longitude': 100.68999467073306,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u83224',
#   'latitude': 13.956970837473841,
#   'longitude': 100.52947975411846,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u88794',
#   'latitude': 14.018257418383167,
#   'longitude': 100.70408572365898,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 1000.0},
#  {'user_id': 'u18426',
#   'latitude': 14.12614212423273,
#   'longitude': 100.62807883865581,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 1000.0},
#  {'user_id': 'u55419',
#   'latitude': 13.970850060766818,
#   'longitude': 100.38228289942266,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u23459',
#   'latitude': 13.762912935438598,
#   'longitude': 100.47114949200947,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u99425',
#   'latitude': 13.885217166384262,
#   'longitude': 100.72096312202456,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u40807',
#   'latitude': 13.751145062276672,
#   'longitude': 100.31354929551448,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 10000.0},
#  {'user_id': 'u35043',
#   'latitude': 13.844523739888821,
#   'longitude': 100.65444450968624,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u32081',
#   'latitude': 13.8575858032128,
#   'longitude': 100.60661239833794,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': nan},
#  {'user_id': 'u65566',
#   'latitude': 14.119646324541192,
#   'longitude': 100.70034301683008,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u02693',
#   'latitude': 14.115930179450936,
#   'longitude': 100.48680165876499,
#   'size': 20,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u67502',
#   'latitude': 14.127974439145257,
#   'longitude': 100.56873133929798,
#   'size': 20,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u69920',
#   'latitude': 13.863420526148223,
#   'longitude': 100.56865795087707,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u95447',
#   'latitude': 14.15042734750678,
#   'longitude': 100.71941358920085,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': nan},
#  {'user_id': 'u72101',
#   'latitude': 13.663317548930786,
#   'longitude': 100.34509289963736,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u13629',
#   'latitude': 14.124879925759176,
#   'longitude': 100.5871332235532,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u27750',
#   'latitude': 13.959165885793704,
#   'longitude': 100.44840435413695,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u54607',
#   'latitude': 14.096203350772461,
#   'longitude': 100.63089916505535,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u33950',
#   'latitude': 13.825251136587122,
#   'longitude': 100.44832593237433,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 1000.0},
#  {'user_id': 'u82958',
#   'latitude': 14.166072774373715,
#   'longitude': 100.41883675759507,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u33082',
#   'latitude': 13.596088203112814,
#   'longitude': 100.4329104120803,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u22644',
#   'latitude': 14.081651030702169,
#   'longitude': 100.80002228041273,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u07297',
#   'latitude': 14.06492108753855,
#   'longitude': 100.50595992649188,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u61580',
#   'latitude': 13.802162803776612,
#   'longitude': 100.79190883490197,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u43800',
#   'latitude': 14.070357347560254,
#   'longitude': 100.71177281581208,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 10000.0},
#  {'user_id': 'u55069',
#   'latitude': 13.707403889332705,
#   'longitude': 100.45354856461445,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u17070',
#   'latitude': 14.025398792890298,
#   'longitude': 100.61137115319657,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u64125',
#   'latitude': 13.857767598237713,
#   'longitude': 100.30954082954479,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 1000.0},
#  {'user_id': 'u74806',
#   'latitude': 13.82392923110861,
#   'longitude': 100.82107932045001,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 1000.0},
#  {'user_id': 'u92160',
#   'latitude': 13.69732753065702,
#   'longitude': 100.65395343507312,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u38705',
#   'latitude': 14.05346600388345,
#   'longitude': 100.36702151169001,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 1000.0},
#  {'user_id': 'u90720',
#   'latitude': 14.012669024139196,
#   'longitude': 100.59194563856997,
#   'size': 20,
#   'sort_dis': 1.0,
#   'max_dis': 1000.0},
#  {'user_id': 'u13762',
#   'latitude': 13.633849573041463,
#   'longitude': 100.57877625296807,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 1000.0},
#  {'user_id': 'u10925',
#   'latitude': 14.158477300974479,
#   'longitude': 100.67597257643364,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u92972',
#   'latitude': 13.711911138495747,
#   'longitude': 100.46487989773077,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u87395',
#   'latitude': 13.80275760467848,
#   'longitude': 100.80830513758904,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u73307',
#   'latitude': 13.826040204422613,
#   'longitude': 100.64934534684807,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u51909',
#   'latitude': 13.921532858941783,
#   'longitude': 100.34494355795734,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': nan},
#  {'user_id': 'u35574',
#   'latitude': 14.106696080246532,
#   'longitude': 100.75791198669218,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': nan},
#  {'user_id': 'u60437',
#   'latitude': 14.139076346274026,
#   'longitude': 100.79435063649818,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u32402',
#   'latitude': 13.955002012241355,
#   'longitude': 100.4731845748463,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u84956',
#   'latitude': 13.797057916595918,
#   'longitude': 100.6984894753199,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u94877',
#   'latitude': 13.644724985412076,
#   'longitude': 100.78086212186639,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u54472',
#   'latitude': 13.621940159033008,
#   'longitude': 100.79289180096076,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 1000.0},
#  {'user_id': 'u10082',
#   'latitude': 13.887511102653233,
#   'longitude': 100.34365402447679,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u46098',
#   'latitude': 13.925498813437088,
#   'longitude': 100.76794782649654,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': nan},
#  {'user_id': 'u79934',
#   'latitude': 13.845243569074944,
#   'longitude': 100.4421594939328,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 10000.0},
#  {'user_id': 'u76734',
#   'latitude': 14.161093658622605,
#   'longitude': 100.74856500501095,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u85904',
#   'latitude': 13.825414844505937,
#   'longitude': 100.68476986934398,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u28929',
#   'latitude': 13.788463605465003,
#   'longitude': 100.56246609260772,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u60971',
#   'latitude': 13.828059125957083,
#   'longitude': 100.803938960718,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u76079',
#   'latitude': 13.682684404858213,
#   'longitude': 100.74936704356558,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': nan},
#  {'user_id': 'u05238',
#   'latitude': 14.135533218389428,
#   'longitude': 100.85510755203309,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u39998',
#   'latitude': 13.930073683875312,
#   'longitude': 100.83538338623093,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u89248',
#   'latitude': 13.901617973383726,
#   'longitude': 100.62202297744355,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 10000.0},
#  {'user_id': 'u79289',
#   'latitude': 13.832618598750862,
#   'longitude': 100.71151429805506,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u12342',
#   'latitude': 13.728876883256262,
#   'longitude': 100.67584729908523,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u71036',
#   'latitude': 13.767457423677863,
#   'longitude': 100.52625192596226,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u93950',
#   'latitude': 13.872597678940055,
#   'longitude': 100.5808130002932,
#   'size': 20,
#   'sort_dis': 0.0,
#   'max_dis': nan},
#  {'user_id': 'u05695',
#   'latitude': 13.844684542684693,
#   'longitude': 100.58580764428237,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 10000.0},
#  {'user_id': 'u15556',
#   'latitude': 14.159231304145544,
#   'longitude': 100.42413809447075,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u49777',
#   'latitude': 13.913609853448929,
#   'longitude': 100.44922037016815,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u54292',
#   'latitude': 13.703478768755001,
#   'longitude': 100.77221201524182,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u19363',
#   'latitude': 13.613010795929755,
#   'longitude': 100.77304951211681,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u94015',
#   'latitude': 13.675258155834735,
#   'longitude': 100.69074043145798,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u71601',
#   'latitude': 13.785400682916983,
#   'longitude': 100.68584808537373,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u64984',
#   'latitude': 14.043080744160413,
#   'longitude': 100.58705061954828,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 10000.0},
#  {'user_id': 'u77750',
#   'latitude': 14.106077048290526,
#   'longitude': 100.6219636892405,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u81940',
#   'latitude': 13.72082417076507,
#   'longitude': 100.67360601881236,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 10000.0},
#  {'user_id': 'u38204',
#   'latitude': 14.041793789232932,
#   'longitude': 100.30877037891192,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u42279',
#   'latitude': 13.841943593832035,
#   'longitude': 100.55029777946893,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u79720',
#   'latitude': 13.89852177496738,
#   'longitude': 100.84147996489358,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u53717',
#   'latitude': 13.895807737685885,
#   'longitude': 100.41857236969632,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u15130',
#   'latitude': 13.606440420708728,
#   'longitude': 100.56347198316746,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u15371',
#   'latitude': 13.62039068652521,
#   'longitude': 100.34762291669838,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u75959',
#   'latitude': 13.975258964440176,
#   'longitude': 100.44585954732231,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u79099',
#   'latitude': 13.987981262948596,
#   'longitude': 100.76087175025738,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u77508',
#   'latitude': 13.80578083645832,
#   'longitude': 100.32284359243228,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u51643',
#   'latitude': 14.123677656631891,
#   'longitude': 100.74688282053644,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 1000.0},
#  {'user_id': 'u34396',
#   'latitude': 14.065199718698915,
#   'longitude': 100.74642042002868,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u72091',
#   'latitude': 13.75950665504184,
#   'longitude': 100.78523944257834,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 1000.0},
#  {'user_id': 'u39941',
#   'latitude': 13.620826385504795,
#   'longitude': 100.44703801304092,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 10000.0},
#  {'user_id': 'u56954',
#   'latitude': 13.90785624213678,
#   'longitude': 100.82034543733583,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u21017',
#   'latitude': 13.967463325279223,
#   'longitude': 100.51048018508136,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u79013',
#   'latitude': 13.713740110203831,
#   'longitude': 100.55399869044982,
#   'size': 20,
#   'sort_dis': 1.0,
#   'max_dis': 1000.0},
#  {'user_id': 'u62987',
#   'latitude': 13.607201989960009,
#   'longitude': 100.83097117711296,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u14371',
#   'latitude': 13.86877052805006,
#   'longitude': 100.60612484182636,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u93500',
#   'latitude': 13.601499072895926,
#   'longitude': 100.68160040065506,
#   'size': 20,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u54971',
#   'latitude': 14.016092782718271,
#   'longitude': 100.36581634829405,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': nan},
#  {'user_id': 'u76515',
#   'latitude': 13.95046087380101,
#   'longitude': 100.30734801257019,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 1000.0},
#  {'user_id': 'u67910',
#   'latitude': 13.74607634500781,
#   'longitude': 100.451174189281,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u45762',
#   'latitude': 13.844334030129122,
#   'longitude': 100.3632289700963,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u48760',
#   'latitude': 13.718785261792032,
#   'longitude': 100.76080019547632,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u90579',
#   'latitude': 13.691048689266148,
#   'longitude': 100.44292933615338,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 1000.0},
#  {'user_id': 'u02449',
#   'latitude': 13.688398554276235,
#   'longitude': 100.83476212281471,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u74155',
#   'latitude': 14.062664001437039,
#   'longitude': 100.68019247270539,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u55859',
#   'latitude': 13.848830300981716,
#   'longitude': 100.4108654010264,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': nan},
#  {'user_id': 'u80934',
#   'latitude': 14.00355378588841,
#   'longitude': 100.69812384212928,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u70892',
#   'latitude': 13.786433601732627,
#   'longitude': 100.48073377956591,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u54318',
#   'latitude': 14.057459690205986,
#   'longitude': 100.59639948308838,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 1000.0},
#  {'user_id': 'u30594',
#   'latitude': 13.932944947946353,
#   'longitude': 100.34673662587736,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u66095',
#   'latitude': 13.967291093561341,
#   'longitude': 100.76569407999885,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': nan},
#  {'user_id': 'u03309',
#   'latitude': 13.81308283554881,
#   'longitude': 100.74046484393334,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u56573',
#   'latitude': 13.912855956069341,
#   'longitude': 100.62624791771769,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u94717',
#   'latitude': 13.69382894802696,
#   'longitude': 100.68700514990428,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 1000.0},
#  {'user_id': 'u80440',
#   'latitude': 14.155965037471995,
#   'longitude': 100.49285814324219,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u25063',
#   'latitude': 13.977993322272697,
#   'longitude': 100.37539721596072,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u89492',
#   'latitude': 13.895550370950165,
#   'longitude': 100.48469299038798,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u24019',
#   'latitude': 13.958255872370978,
#   'longitude': 100.71426299468132,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 1000.0},
#  {'user_id': 'u74192',
#   'latitude': 13.640434241338804,
#   'longitude': 100.61639975680117,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u42889',
#   'latitude': 13.778688663129632,
#   'longitude': 100.37925930909336,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u17803',
#   'latitude': 13.717443145976047,
#   'longitude': 100.43797286239005,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u41593',
#   'latitude': 14.078862697854143,
#   'longitude': 100.56765911332877,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 10000.0},
#  {'user_id': 'u68280',
#   'latitude': 13.588935030710957,
#   'longitude': 100.31269546957856,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u70723',
#   'latitude': 13.843717808464573,
#   'longitude': 100.32949928421269,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 10000.0},
#  {'user_id': 'u29323',
#   'latitude': 14.093894678405114,
#   'longitude': 100.55370949111472,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u54096',
#   'latitude': 14.043147080176475,
#   'longitude': 100.37881208268098,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u07405',
#   'latitude': 14.005516860982857,
#   'longitude': 100.7967441591254,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u54859',
#   'latitude': 13.7592584026478,
#   'longitude': 100.375969306733,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 1000.0},
#  {'user_id': 'u19465',
#   'latitude': 13.718413738802608,
#   'longitude': 100.71946558177032,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u32309',
#   'latitude': 13.996959674442554,
#   'longitude': 100.74458381796288,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u77921',
#   'latitude': 13.757570168417432,
#   'longitude': 100.47931779780477,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u98734',
#   'latitude': 14.008038351620225,
#   'longitude': 100.60474498858885,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u88672',
#   'latitude': 13.787863244084615,
#   'longitude': 100.85385894401229,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u49714',
#   'latitude': 14.030181636492932,
#   'longitude': 100.64630540120311,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u78931',
#   'latitude': 13.919482957796923,
#   'longitude': 100.51900871589177,
#   'size': 20,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u23526',
#   'latitude': 14.062530428256764,
#   'longitude': 100.84490441920279,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u26390',
#   'latitude': 14.162977770566215,
#   'longitude': 100.44844645878914,
#   'size': 20,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u94064',
#   'latitude': 13.804744665776735,
#   'longitude': 100.83351827924882,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 1000.0},
#  {'user_id': 'u06033',
#   'latitude': 14.16349529272887,
#   'longitude': 100.47627697708383,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u45184',
#   'latitude': 13.587205950156727,
#   'longitude': 100.53802761579972,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u70432',
#   'latitude': 14.099036624958668,
#   'longitude': 100.47943715468436,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u46069',
#   'latitude': 13.59890368624353,
#   'longitude': 100.66556495556884,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u84595',
#   'latitude': 13.903103128506165,
#   'longitude': 100.79314080561352,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u51931',
#   'latitude': 13.810456346989097,
#   'longitude': 100.68616683416788,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u77347',
#   'latitude': 14.035642869073579,
#   'longitude': 100.40545917443137,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u51850',
#   'latitude': 13.767235685198054,
#   'longitude': 100.85287769313574,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u46864',
#   'latitude': 13.704209531942253,
#   'longitude': 100.70478005379243,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u37391',
#   'latitude': 14.044025689131212,
#   'longitude': 100.58493686417856,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': nan},
#  {'user_id': 'u75946',
#   'latitude': 13.906088596510536,
#   'longitude': 100.77502060960414,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 1000.0},
#  {'user_id': 'u90710',
#   'latitude': 14.027249472941223,
#   'longitude': 100.36410091581116,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u77121',
#   'latitude': 13.870092432107759,
#   'longitude': 100.63576935834242,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u74381',
#   'latitude': 13.602923521849245,
#   'longitude': 100.7397116184583,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u47117',
#   'latitude': 14.036422169903954,
#   'longitude': 100.73457320230825,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 1000.0},
#  {'user_id': 'u37250',
#   'latitude': 13.710040221163544,
#   'longitude': 100.67721005800358,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u64316',
#   'latitude': 13.859759508505375,
#   'longitude': 100.3393512843587,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u33495',
#   'latitude': 13.581651899320532,
#   'longitude': 100.56951570185335,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u61641',
#   'latitude': 13.734160468890733,
#   'longitude': 100.45348812699078,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u39398',
#   'latitude': 13.974125417235197,
#   'longitude': 100.64123763437918,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': nan},
#  {'user_id': 'u03993',
#   'latitude': 14.032283345951512,
#   'longitude': 100.52441264431528,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u25246',
#   'latitude': 13.956906702413843,
#   'longitude': 100.55704779392177,
#   'size': 20,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u57981',
#   'latitude': 13.842884772255687,
#   'longitude': 100.60246049043177,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 1000.0},
#  {'user_id': 'u91866',
#   'latitude': 14.013737240274352,
#   'longitude': 100.63036453139809,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u90856',
#   'latitude': 13.97604959301495,
#   'longitude': 100.79753508037732,
#   'size': 20,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u02008',
#   'latitude': 13.70289261161974,
#   'longitude': 100.46088890131304,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u47854',
#   'latitude': 13.897122931254538,
#   'longitude': 100.45684341645449,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 10000.0},
#  {'user_id': 'u83633',
#   'latitude': 13.934137631054092,
#   'longitude': 100.40680195675179,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u15419',
#   'latitude': 14.011395209280401,
#   'longitude': 100.36699498471548,
#   'size': 20,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u12145',
#   'latitude': 13.698016593057133,
# ...
#   'max_dis': 5000.0},
#  {'user_id': 'u37602',
#   'latitude': 13.937025357161867,
#   'longitude': 100.70212255444784,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u89949',
#   'latitude': 13.785981347699911,
#   'longitude': 100.49406397362404,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u69501',
#   'latitude': 14.156982255646373,
#   'longitude': 100.64023345703745,
#   'size': 20,
#   'sort_dis': nan,
#   'max_dis': 10000.0},
#  {'user_id': 'u66166',
#   'latitude': 14.14556778444669,
#   'longitude': 100.71213253894393,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u52299',
#   'latitude': 14.010172570225123,
#   'longitude': 100.51594294792687,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u51767',
#   'latitude': 14.068757553038127,
#   'longitude': 100.68202333955189,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 1000.0},
#  {'user_id': 'u92431',
#   'latitude': 13.625748239945825,
#   'longitude': 100.80480748696407,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u85075',
#   'latitude': 13.654308076527206,
#   'longitude': 100.5091675524363,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u30162',
#   'latitude': 13.78525765006824,
#   'longitude': 100.59595529021735,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u00245',
#   'latitude': 13.655776358423598,
#   'longitude': 100.57258462183573,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u97991',
#   'latitude': 13.830669703402789,
#   'longitude': 100.76890632624034,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u36769',
#   'latitude': 14.163228304354266,
#   'longitude': 100.45414087181628,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u50302',
#   'latitude': 14.073750179593402,
#   'longitude': 100.46307855866326,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u82620',
#   'latitude': 14.147090881439375,
#   'longitude': 100.52198430554947,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u36496',
#   'latitude': 13.71211646583789,
#   'longitude': 100.66578334627522,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u05891',
#   'latitude': 13.712231792711256,
#   'longitude': 100.39021064641888,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 1000.0},
#  {'user_id': 'u43511',
#   'latitude': 13.595135325093805,
#   'longitude': 100.84633089083465,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u56071',
#   'latitude': 13.742824495465959,
#   'longitude': 100.5831496223485,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u03076',
#   'latitude': 13.614667294117487,
#   'longitude': 100.70906759599045,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u51684',
#   'latitude': 13.892996394770977,
#   'longitude': 100.53297389020271,
#   'size': 20,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u20199',
#   'latitude': 13.758710250019913,
#   'longitude': 100.31981116454665,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u06925',
#   'latitude': 13.978931060745607,
#   'longitude': 100.5181394316126,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u69340',
#   'latitude': 13.912418451320109,
#   'longitude': 100.62106154613608,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u64913',
#   'latitude': 13.93383654924541,
#   'longitude': 100.3547368353916,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u02440',
#   'latitude': 13.75828106616899,
#   'longitude': 100.84718701547924,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u36341',
#   'latitude': 14.014958262470172,
#   'longitude': 100.62967398236337,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u12408',
#   'latitude': 13.98802731674741,
#   'longitude': 100.55881498150191,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 1000.0},
#  {'user_id': 'u97436',
#   'latitude': 14.0028376288513,
#   'longitude': 100.32064991771193,
#   'size': 20,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u41028',
#   'latitude': 13.859337037751564,
#   'longitude': 100.44117080226087,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 10000.0},
#  {'user_id': 'u99475',
#   'latitude': 13.855068304070235,
#   'longitude': 100.49140181856356,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u86536',
#   'latitude': 13.750077578673926,
#   'longitude': 100.664265332951,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': nan},
#  {'user_id': 'u49210',
#   'latitude': 13.604985489058379,
#   'longitude': 100.40108652745108,
#   'size': 20,
#   'sort_dis': 1.0,
#   'max_dis': 1000.0},
#  {'user_id': 'u78112',
#   'latitude': 13.856325648334032,
#   'longitude': 100.57320814968669,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 10000.0},
#  {'user_id': 'u21171',
#   'latitude': 13.944969381841188,
#   'longitude': 100.45455852561271,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': nan},
#  {'user_id': 'u32688',
#   'latitude': 13.691157052004117,
#   'longitude': 100.61732363721055,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 10000.0},
#  {'user_id': 'u17242',
#   'latitude': 14.088843403122448,
#   'longitude': 100.6855982723124,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 1000.0},
#  {'user_id': 'u88407',
#   'latitude': 14.10004710640542,
#   'longitude': 100.59137366599397,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u76615',
#   'latitude': 14.085038735486375,
#   'longitude': 100.71995302946128,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': nan},
#  {'user_id': 'u71352',
#   'latitude': 14.062926228017707,
#   'longitude': 100.64942238208972,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 1000.0},
#  {'user_id': 'u67533',
#   'latitude': 13.869517347108365,
#   'longitude': 100.35099941567555,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u61379',
#   'latitude': 13.68503544157923,
#   'longitude': 100.66819879523331,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': nan},
#  {'user_id': 'u46467',
#   'latitude': 13.741324320141647,
#   'longitude': 100.57251910680993,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u27205',
#   'latitude': 14.016611589885645,
#   'longitude': 100.72488067727897,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 10000.0},
#  {'user_id': 'u14825',
#   'latitude': 14.162368842982657,
#   'longitude': 100.82341355496887,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u81856',
#   'latitude': 13.646978823945009,
#   'longitude': 100.49933198056713,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u11688',
#   'latitude': 13.585019347018315,
#   'longitude': 100.77522908010951,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 10000.0},
#  {'user_id': 'u44744',
#   'latitude': 13.789810978447399,
#   'longitude': 100.43200741688445,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': nan},
#  {'user_id': 'u15925',
#   'latitude': 13.787428599421304,
#   'longitude': 100.66456348766631,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u85168',
#   'latitude': 13.93402521336468,
#   'longitude': 100.30776306654649,
#   'size': 20,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u54430',
#   'latitude': 13.647611394101068,
#   'longitude': 100.76132126220618,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u19987',
#   'latitude': 14.07929988115583,
#   'longitude': 100.55163093751842,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': nan},
#  {'user_id': 'u13372',
#   'latitude': 13.780818363482684,
#   'longitude': 100.55637433272624,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u24732',
#   'latitude': 14.117493518421181,
#   'longitude': 100.58017192528519,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u60728',
#   'latitude': 13.77562744521634,
#   'longitude': 100.51084572416359,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u85599',
#   'latitude': 13.761515809309559,
#   'longitude': 100.4320262557174,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 1000.0},
#  {'user_id': 'u28146',
#   'latitude': 13.685093551325396,
#   'longitude': 100.68787208542813,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': nan},
#  {'user_id': 'u83077',
#   'latitude': 14.151202045658856,
#   'longitude': 100.65183077644572,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 10000.0},
#  {'user_id': 'u61699',
#   'latitude': 13.929180668379535,
#   'longitude': 100.3348561868633,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u31087',
#   'latitude': 14.068536557301137,
#   'longitude': 100.4544270384468,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u54745',
#   'latitude': 13.618532529725604,
#   'longitude': 100.82040728330848,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 1000.0},
#  {'user_id': 'u78272',
#   'latitude': 13.901712991248903,
#   'longitude': 100.46129087533592,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u51566',
#   'latitude': 14.013910677020863,
#   'longitude': 100.46715096281821,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 1000.0},
#  {'user_id': 'u85494',
#   'latitude': 14.161915115559623,
#   'longitude': 100.62470237232273,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u50396',
#   'latitude': 14.13403972519304,
#   'longitude': 100.51100626550841,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 1000.0},
#  {'user_id': 'u76430',
#   'latitude': 13.642632744045097,
#   'longitude': 100.8292558476275,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u27687',
#   'latitude': 13.801584348476672,
#   'longitude': 100.84865922584817,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 1000.0},
#  {'user_id': 'u60877',
#   'latitude': 14.17070955023209,
#   'longitude': 100.37617519494741,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u27588',
#   'latitude': 13.896966569044773,
#   'longitude': 100.42921380370919,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u37575',
#   'latitude': 14.146041565226803,
#   'longitude': 100.39936050042728,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 1000.0},
#  {'user_id': 'u90497',
#   'latitude': 13.730909012099517,
#   'longitude': 100.55089143962074,
#   'size': 20,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u23427',
#   'latitude': 13.596403883603593,
#   'longitude': 100.461861640743,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u40920',
#   'latitude': 14.139696493280068,
#   'longitude': 100.67799734204935,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 10000.0},
#  {'user_id': 'u30334',
#   'latitude': 13.736994893561006,
#   'longitude': 100.79488245276467,
#   'size': 20,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u13696',
#   'latitude': 13.912174275201153,
#   'longitude': 100.34423595700693,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u79464',
#   'latitude': 13.794125585757286,
#   'longitude': 100.31920129372486,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 10000.0},
#  {'user_id': 'u50573',
#   'latitude': 13.922156060866387,
#   'longitude': 100.36676977469229,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u89735',
#   'latitude': 14.132394431695705,
#   'longitude': 100.4762715036706,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u59358',
#   'latitude': 14.140106673068061,
#   'longitude': 100.3787949176079,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u33089',
#   'latitude': 14.098886866900157,
#   'longitude': 100.54373499470533,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 1000.0},
#  {'user_id': 'u52249',
#   'latitude': 13.732832590880038,
#   'longitude': 100.50593930062736,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u50509',
#   'latitude': 14.065803047880877,
#   'longitude': 100.70731218581487,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': nan},
#  {'user_id': 'u79339',
#   'latitude': 13.592177010684125,
#   'longitude': 100.83997073002755,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': nan},
#  {'user_id': 'u52856',
#   'latitude': 13.827043863792744,
#   'longitude': 100.84580771336951,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u86435',
#   'latitude': 14.138479259804837,
#   'longitude': 100.53748819347545,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u57084',
#   'latitude': 13.73155890040839,
#   'longitude': 100.66073968095174,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u94513',
#   'latitude': 13.7980275100745,
#   'longitude': 100.37790492699952,
#   'size': 20,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u44474',
#   'latitude': 13.924658413564849,
#   'longitude': 100.64263741295753,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': nan},
#  {'user_id': 'u60134',
#   'latitude': 13.720962650649748,
#   'longitude': 100.79379210733693,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u52175',
#   'latitude': 13.999367839372406,
#   'longitude': 100.79461651047656,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u29162',
#   'latitude': 13.966381789499847,
#   'longitude': 100.38227888951215,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u29528',
#   'latitude': 13.637423707290829,
#   'longitude': 100.39664043983453,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u88289',
#   'latitude': 14.124302115658116,
#   'longitude': 100.8039056422224,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u19997',
#   'latitude': 13.623522880058788,
#   'longitude': 100.69070713239884,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 10000.0},
#  {'user_id': 'u60565',
#   'latitude': 13.992367282091523,
#   'longitude': 100.72674100947833,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u61913',
#   'latitude': 13.786914711846594,
#   'longitude': 100.34197065175803,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u28773',
#   'latitude': 13.666055651545868,
#   'longitude': 100.64707351224888,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u83939',
#   'latitude': 13.62735053570895,
#   'longitude': 100.31737414266412,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u66915',
#   'latitude': 14.170114211614553,
#   'longitude': 100.71254279332388,
#   'size': 20,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u13877',
#   'latitude': 14.05323385686312,
#   'longitude': 100.74457258025149,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 10000.0},
#  {'user_id': 'u62446',
#   'latitude': 13.852084939895882,
#   'longitude': 100.48295413834661,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u14476',
#   'latitude': 14.050234100751712,
#   'longitude': 100.30629707528372,
#   'size': 20,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u22706',
#   'latitude': 14.153624886225552,
#   'longitude': 100.71041187533359,
#   'size': 50,
#   'sort_dis': 0.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u72213',
#   'latitude': 14.128010809512931,
#   'longitude': 100.85732893877702,
#   'size': 20,
#   'sort_dis': 1.0,
#   'max_dis': 1000.0},
#  {'user_id': 'u78872',
#   'latitude': 13.895582627936268,
#   'longitude': 100.64819992315691,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 10000.0},
#  {'user_id': 'u65973',
#   'latitude': 13.743560384701336,
#   'longitude': 100.50732249173345,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': nan},
#  {'user_id': 'u45160',
#   'latitude': 13.887319718049378,
#   'longitude': 100.48680923565242,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  {'user_id': 'u34017',
#   'latitude': 14.16044043919079,
#   'longitude': 100.7541237875262,
#   'size': 20,
#   'sort_dis': 0.0,
#   'max_dis': 10000.0},
#  {'user_id': 'u87273',
#   'latitude': 14.012259654365291,
#   'longitude': 100.84090427144315,
#   'size': 50,
#   'sort_dis': nan,
#   'max_dis': 5000.0},
#  {'user_id': 'u11394',
#   'latitude': 13.976573055123197,
#   'longitude': 100.50677144500808,
#   'size': 50,
#   'sort_dis': 1.0,
#   'max_dis': 5000.0},
#  ...]

# %%
request_df.isnull().sum()
# Out:
# user_id        0
# latitude       0
# longitude      0
# size           0
# sort_dis     589
# max_dis      192
# dtype: int64

# %%
request_df[request_df["user_id"] == "u83153"]
# Out:
#   user_id   latitude   longitude  size  sort_dis  max_dis
# 0  u83153  14.068817  100.646536    50       0.0   5000.0

# %%
request_df["sort_dis"].value_counts()
# Out:
# sort_dis
# 1.0    786
# 0.0    625
# Name: count, dtype: int64

# %%
request_df["size"].value_counts()
# Out:
# size
# 50    1788
# 20     212
# Name: count, dtype: int64

# %%
request_df["max_dis"].value_counts()
# Out:
# max_dis
# 5000.0     1411
# 1000.0      208
# 10000.0     189
# Name: count, dtype: int64
